# %% [markdown]
# Total \22534
# ubuntu@ip-172-31-25-3:~/planet-snowcover$ rclone ls  gdrive-web:Planet_Archive | head
# 601624497 PSScene4Band_20190729_173036_100c_all_udm2.zip
# 612212889 PSScene4Band_20190729_173035_100c_all_udm2.zip
# 637162048 PSScene4Band_20190729_173034_100c_all_udm2.zip
# 635039351 PSScene4Band_20190729_173033_100c_all_udm2.zip
# 647824951 PSScene4Band_20190729_173032_100c_all_udm2.zip
# 665999371 PSScene4Band_20190729_173029_100c_all_udm2.zip
# 651668411 PSScene4Band_20190729_172854_1009_all_udm2.zip
# 642603171 PSScene4Band_20190729_172853_1009_all_udm2.zip
# 632319732 PSScene4Band_20190729_172848_1009_all_udm2.zip
# 633600393 PSScene4Band_20190729_172847_1009_all_udm2.zip

# %%
# !rclone copy gdrive-web:Planet_Archive/PSScene4Band_20190729_172847_1009_all_udm2.zip .

# %%
# !rclone copy gdrive-web:Planet_Archive/PSScene4Band_20170125_175925_0e20_all_udm2.zip .

# %%
# !ls -l PSScene4Band_20190729_172847_1009_all_udm2.zip
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 633600393 Jun 20 05:46 PSScene4Band_20190729_172847_1009_all_udm2.zip

# %%
import zipfile
archive = zipfile.ZipFile('PSScene4Band_20190729_172847_1009_all_udm2.zip', 'r')
print(archive.testzip())
print(archive.printdir())
imgdata = archive.read('files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_3B_AnalyticMS_SR.tif')
# Out:
# None
# File Name                                             Modified             Size
# files/PSScene4Band/20190729_172847_1009/20190729_172847_1009_metadata.json 2019-11-08 18:48:28         1165
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1A_udm2.tif 2019-11-08 18:48:28      1803790
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1B_AnalyticMS.tif 2019-11-08 18:48:28    110232902
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1B_AnalyticMS_DN.tif 2019-11-08 18:48:30     69179944
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1B_AnalyticMS_DN_metadata.xml 2019-11-08 18:48:30         8915
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1B_AnalyticMS_DN_udm.tif 2019-11-08 18:48:30       444969
# files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_1B_AnalyticMS_RPC.TXT 2019-11-08 18:48:30         3361
# ...

# %%
# Open the DEM raster already in  epsg4326
# %matplotlib inline
import rasterio as rio
import numpy as np
from matplotlib import pyplot as plt
import rasterio.plot
import os
from datetime import datetime as dt
with rasterio.open('zip://PSScene4Band_20190729_172847_1009_all_udm2.zip!files/PSScene4Band/20190729_172847_1009/all_udm2/20190729_172847_1009_3B_AnalyticMS_SR.tif') as dataset:
    print(dataset.profile)
    elev = dataset.read(1)
    print(dataset.meta)
    # Plot this reprojected  elevation band:
    plt.figure(figsize=(10,10))
    plt.imshow(elev)
    plt.colorbar()
    title_text = ''
    plt.title(title_text);
# Out:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 9072, 'height': 4685, 'count': 4, 'crs': CRS.from_epsg(32613), 'transform': Affine(3.0, 0.0, 340170.0,
#        0.0, -3.0, 4216314.0), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'pixel'}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 9072, 'height': 4685, 'count': 4, 'crs': CRS.from_epsg(32613), 'transform': Affine(3.0, 0.0, 340170.0,
#        0.0, -3.0, 4216314.0)}

# %%
archive = zipfile.ZipFile('PSScene4Band_20170125_175925_0e20_all_udm2.zip', 'r')
print(archive.testzip())
print(archive.printdir())
# Out:
# None
# File Name                                             Modified             Size
# files/PSScene4Band/20170125_175925_0e20/20170125_175925_0e20_metadata.json 2019-11-08 18:39:40         1109
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1A_udm2.tif 2019-11-08 18:39:40      1616726
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1B_AnalyticMS.tif 2019-11-08 18:39:40    127876486
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1B_AnalyticMS_DN.tif 2019-11-08 18:39:40     96829636
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1B_AnalyticMS_DN_metadata.xml 2019-11-08 18:39:40         8923
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1B_AnalyticMS_DN_udm.tif 2019-11-08 18:39:40       784652
# files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_1B_AnalyticMS_RPC.TXT 2019-11-08 18:39:40         3268
# ...

# %% [markdown]
# 668263763 PSScene4Band_20170125_175934_0e20_all_udm2.zip
# 690502590 PSScene4Band_20170125_175933_0e20_all_udm2.zip
# 699771954 PSScene4Band_20170125_175932_0e20_all_udm2.zip
# 752106608 PSScene4Band_20170125_175931_0e20_all_udm2.zip
# 812948584 PSScene4Band_20170125_175930_0e20_all_udm2.zip
# 789961947 PSScene4Band_20170125_175929_0e20_all_udm2.zip
# 811056040 PSScene4Band_20170125_175928_0e20_all_udm2.zip
# 841358874 PSScene4Band_20170125_175927_0e20_all_udm2.zip
# 827957251 PSScene4Band_20170125_175926_0e20_all_udm2.zip
# 799406642 PSScene4Band_20170125_175925_0e20_all_udm2.zip

# %%
# Open the DEM raster already in  epsg4326
# %matplotlib inline
import rasterio as rio
import numpy as np
from matplotlib import pyplot as plt
import rasterio.plot
import os
from datetime import datetime as dt
with rasterio.open('zip://PSScene4Band_20170125_175925_0e20_all_udm2.zip!files/PSScene4Band/20170125_175925_0e20/all_udm2/20170125_175925_0e20_3B_AnalyticMS_SR.tif') as dataset:
    print(dataset.profile)
    elev = dataset.read(1)
    print(dataset.meta)
    # Plot this reprojected  elevation band:
    plt.figure(figsize=(10,10))
    plt.imshow(elev)
    plt.colorbar()
    title_text = ''
    plt.title(title_text);
# Out:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 9056, 'height': 4912, 'count': 4, 'crs': CRS.from_epsg(32611), 'transform': Affine(3.0, 0.0, 253527.0,
#        0.0, -3.0, 4199847.0), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'pixel'}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 9056, 'height': 4912, 'count': 4, 'crs': CRS.from_epsg(32611), 'transform': Affine(3.0, 0.0, 253527.0,
#        0.0, -3.0, 4199847.0)}

# %%
# !pip install google-api-python-client
# Out:
# ...
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install oauth2client
# Out:
# ...
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install httplib2==0.17.3
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/18/9b/b95a08c373819376bf3f109bdbcff6bd4f69f2340bf708a252380319037a/httplib2-0.17.3-py3-none-any.whl
# ...
#   Found existing installation: httplib2 0.15.0
#     Uninstalling httplib2-0.15.0:
#       Successfully uninstalled httplib2-0.15.0
# ...
# You are using pip version 9.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/drive.metadata.readonly']

def drivemain():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'client_secret_uw.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('drive', 'v3', credentials=creds)

    # Call the Drive v3 API
    results = service.files().list(
        pageSize=10, fields="nextPageToken, files(id, name)").execute()
    items = results.get('files', [])

    if not items:
        print('No files found.')
    else:
        print('Files:')
        for item in items:
            print(u'{0} ({1})'.format(item['name'], item['id']))

# %%
drivemain()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=67364944234-cduvoeuqc5oi866iftikto8r0dq6krgn.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A43070%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.metadata.readonly&state=h3Ul3LYnAhbqiDYXZ4c9HIUdxtQbzq&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-9b529765b565> in <module>()
# ----> 1 drivemain()
#
# <ipython-input-32-406bd5012cd6> in drivemain()
#      27             flow = InstalledAppFlow.from_client_secrets_file(
#      28                 'client_secret_uw.json', SCOPES)
# ---> 29             creds = flow.run_local_server(port=0)
#      30         # Save the credentials for the next run
#      31         with open('token.pickle', 'wb') as token:
#
# ...

# %%
from apiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials
from httplib2 import Http
from apiclient.http import MediaFileUpload
from apiclient import discovery
from googleapiclient.errors import HttpError
scopes = ['https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name('uw-mino.json', scopes)

http_auth = credentials.authorize(Http())
#drive = build('drive', 'v3', http=http_auth)
drive = discovery.build('drive', 'v2', http=http_auth)
request = drive.files().list().execute()
files = request.get('items', [])
for f in files:
    print(f)
    
parentFolderId = "Funding"
file_metadata = {
        'name': 'output_4_1.png',
        'parents': [parentFolderId]
    }
# source
media = MediaFileUpload('output_4_1.png',
                            mimetype='image/png',
                            resumable=True)
# TODO
# chunk upload: https://developers.google.com/api-client-library/python/guide/media_upload
request = drive.files().insert(body=file_metadata,
                                     media_body=media,
                                     fields='id')

response = None
while response is None:
        status, response = request.next_chunk()
        if status:
            print("Uploaded{}".format(int(status.progress() * 100)))
print("Upload Complete!")
# Out:
# {'kind': 'drive#file', 'id': '1--R1vOaPTB1v_KsK3sW8ZiNcAfocnbJb', 'etag': '"MTU4ODgyOTEzOTgwNg"', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1--R1vOaPTB1v_KsK3sW8ZiNcAfocnbJb', 'webContentLink': 'https://drive.google.com/uc?id=1--R1vOaPTB1v_KsK3sW8ZiNcAfocnbJb&export=download', 'alternateLink': 'https://drive.google.com/file/d/1--R1vOaPTB1v_KsK3sW8ZiNcAfocnbJb/view?usp=drivesdk', 'embedLink': 'https://drive.google.com/file/d/1--R1vOaPTB1v_KsK3sW8ZiNcAfocnbJb/preview?usp=drivesdk', 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/image/png', 'thumbnailLink': 'https://lh3.googleusercontent.com/fAkDptQxXTKAaRum8C7Zsf1bIvsz__w42WZp7YCf-aEwUsd0s40Dt2vk29gsAvfad8swb-igiyE=s220', 'title': 'output_4_1.png', 'mimeType': 'image/png', 'description': 'plot stuff', 'labels': {'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'viewed': True}, 'copyRequiresWriterPermission': False, 'createdDate': '2020-05-07T05:25:39.806Z', 'modifiedDate': '202
# ...

# %%
def insert_file(service, title, description, parent_id, mime_type, filename):
  """Insert new file.

  Args:
    service: Drive API service instance.
    title: Title of the file to insert, including the extension.
    description: Description of the file to insert.
    parent_id: Parent folder's ID.
    mime_type: MIME type of the file to insert.
    filename: Filename of the file to insert.
  Returns:
    Inserted file metadata if successful, None otherwise.
  """
  media_body = MediaFileUpload(filename, mimetype=mime_type, resumable=True)
  body = {
    'title': title,
    'description': description,
    'mimeType': mime_type
  }
  # Set the parent folder.
  if parent_id:
    body['parents'] = [{'id': parent_id}]

  try:
    file = service.files().insert(
        body=body,
        media_body=media_body).execute()

    # Uncomment the following line to print the File ID
    print( 'File ID: %s' % file['id'])

    return file
  except HttpError as err:
    print('An error occurred: %s' % err)
    return None

# %%
## source
#media = MediaFileUpload('output_4_1.png',
#                            mimetype='image/png',
#                            resumable=True)

insert_file(drive,'output_4_1.png','plot stuff',parent_id='1qxKJqjKbRlKfiTpAacThn6U-iHFBd1Vh',mime_type='image/png',filename='output_4_1.png')
# Out:
# File ID: 1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ
# {'kind': 'drive#file',
#  'id': '1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ',
#  'etag': '"MTU4ODgyOTMyNDM3Mg"',
#  'selfLink': 'https://www.googleapis.com/drive/v2/files/1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ',
#  'webContentLink': 'https://drive.google.com/uc?id=1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ&export=download',
#  'alternateLink': 'https://drive.google.com/file/d/1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ/view?usp=drivesdk',
#  'embedLink': 'https://drive.google.com/file/d/1tuBwHdmjNm70ij-cXeyhQgpWIsKOz2BJ/preview?usp=drivesdk',
#  'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/image/png',
#  'thumbnailLink': 'https://lh3.googleusercontent.com/zJsy3S8u5acXRat_SzvdApPkTXiaeWikfzRZS2szmeB1HotHGsurbaUttt8xkV7scDrRQfAjknE=s220',
#  'title': 'output_4_1.png',
#  'mimeType': 'image/png',
#  'description': 'plot stuff',
#  'labels': {'starred': False,
#   'hidden': False,
#   'trashed': False,
#   'restricted': False,
#   'viewed': True},
# ...

# %%
import pprint
import s3fs
import boto3
import io
from re import match
# %matplotlib inline
import rasterio as rio

p = pprint.PrettyPrinter()

fs = s3fs.S3FileSystem(session = boto3.Session(profile_name = 'esip'))
#dem only
imagery_searchpath = 's3://planet-snowcover-archive'
#print("Searching for imagery...({})".format(imagery_searchpath))
imagery_candidates = fs.ls(imagery_searchpath)
print("candidates:")
#p.pprint(imagery_candidates)
# filter only the test scenes tiles
archived_files = [link for link  in imagery_candidates if link.endswith('zip')]
#p.pprint(archived_files)
# Out:
# candidates:

# %%
len(archived_files)
# Out:
# 22534

# %%
# !rclone copy PSScene4Band_20170125_175925_0e20_all_udm2.zip gdrive-web:Planet_Archive

# %%
archived_files[0]
# Out:
# 'planet-snowcover-archive/PSScene4Band_20170125_175925_0e20_all_udm2.zip'

# %%
import boto3
session = boto3.Session(profile_name='esip')
# Any clients created from this session will use credentials
# from the [dev] section of ~/.aws/credentials.
dev_s3_client = session.client('s3')
countCopied = 0
for link in archived_files:
    folder = link.split('/')[0]
    archive_file= link.split('/')[1]
    with open(archive_file, 'wb') as f:
        dev_s3_client.download_fileobj(folder, archive_file, f)
    # !rclone copy {archive_file} gdrive-web:Planet_Archive
    # !rm {archive_file}
    countCopied = countCopied+1
    print("copied",archive_file )
# Out:
# copied PSScene4Band_20170125_175925_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175926_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175927_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175928_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175929_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175930_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175931_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175932_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175933_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175934_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175935_0e20_all_udm2.zip
# copied PSScene4Band_20170125_175936_0e20_all_udm2.zip
# copied PSScene4Band_20170329_170838_0f18_all_udm2.zip
# copied PSScene4Band_20170408_165902_1009_all_udm2.zip
# copied PSScene4Band_20170408_165903_1009_all_udm2.zip
# copied PSScene4Band_20170408_171007_1025_all_udm2.zip
# copied PSScene4Band_20170430_170220_1019_all_udm2.zip
# ...
