# %%
# !export CURL_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt

# %%
# %matplotlib inline
from osgeo import gdal
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import rasterio as rio
import numpy as np
from matplotlib import pyplot as plt
import rasterio.plot
import os
from datetime import datetime as dt
from rasterio import Affine, MemoryFile
from rasterio.enums import Resampling
import numpy
scale=1

# %%
# Validate the see if the clips can be used.
# %matplotlib inline
from os import environ
import sys
import io
from os.path import expanduser
import pprint
import s3fs
import boto3
import io
from re import match
# %matplotlib inline
import rasterio as rio

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
import numpy as np
import numpy
# %matplotlib inline
import rasterio as rio
from matplotlib import pyplot as plt
import rasterio.plot
import os
from datetime import datetime as dt
from rasterio.io import MemoryFile
import tempfile

sys.path.append("../model/robosat_pink/")
from robosat_pink.config import load_config
config_location= '/home/ubuntu/planet-snowcover/experiments/co-train.toml'
config = load_config(config_location)


p = pprint.PrettyPrinter()

fs = s3fs.S3FileSystem(session = boto3.Session(profile_name = config['dataset']['aws_profile']))

imagery_searchpath = config['dataset']['image_bucket']  + '/' +  config['dataset']['imagery_directory_regex']
print("Searching for imagery...({})".format(imagery_searchpath))
imagery_candidates = fs.ls(config['dataset']['image_bucket'])
#print("candidates:")
#p.pprint(imagery_candidates)
imagery_locs = [c for c in imagery_candidates if match(imagery_searchpath, c)]
print("result:")
p.pprint(imagery_locs)
# Out:
# Searching for imagery...(planet-snowcover-imagery/20180528_.*)
# result:
# ['planet-snowcover-imagery/20180528_180846_1002_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_180847_1002_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181107_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181108_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181109_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181110_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181111_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181112_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181113_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181114_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181115_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181116_1025_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181319_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181320_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181322_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181323_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181324_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181325_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181326_1005_3B_AnalyticMS_SR_clip',
#  'planet-snowcover-imagery/20180528_181327_1005_3B_AnalyticMS_SR_clip']

# %%
# !export CURL_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt

# %%
#Revised

#Now we got main root clips
#Now check that for each image, you can get the DEM clipped
import pandas as pd
import pyproj
from geopandas import GeoDataFrame
from shapely.geometry import shape,box
from rasterio.mask import mask
from rasterio.transform import from_origin
scale=1
#create the files with 5 babds
for link in imagery_locs:
    print(link)
    #sub_candidates = fs.ls(link)
    #print(sub_candidates)
    #dev_s3_client.list_objects(link) 
    s3 = boto3.resource('s3')
    s3_client = boto3.client('s3')

    bucket=link.partition('/')[0] 
    my_bucket = s3.Bucket(bucket)
    for my_bucket_object in my_bucket.objects.filter(Prefix=link.partition('/')[2]):
        #print(my_bucket_object)
        print('{0}:{1}'.format(my_bucket.name, my_bucket_object.key))
        with rio.open('s3://{0}/{1}'.format(my_bucket.name, my_bucket_object.key)) as src:
            print("key",my_bucket_object.key)
            print(src.meta)
            # # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
            planet_ndvi = es.normalized_diff(src.read(3), src.read(4))
            aug_pla_meta = src.profile
            # Change the count or number of bands from 4 to 5
            aug_pla_meta['count'] = 5
            # Change the data type to float rather than integer
            aug_pla_meta['dtype'] = "float64"
            aug_pla_meta
            
            #convert to float64
            #ndvi_64 = np.array(planet_ndvi, dtype=numpy.float64)
            t = src.transform
            # rescale the metadata
            transform = Affine(t.a * scale, t.b, t.c, t.d, t.e * scale, t.f)
            height = int(src.height / scale)
            width = int(src.width / scale)
            
            #clip the dem
            with rio.open('out.tiff') as origin:

                epsg4326_dem = origin.read(1)
                print('dem meta origin',origin.meta)

                print('planet origin',src.meta)
                #pf = src.read(1, masked=True)
                print(box(*src.bounds))
                
                try:
                    clipped_raster,clipped_transform = mask(origin,[box(*src.bounds)],crop=True,nodata= 0)
                except ValueError as err:
                     print('Handling run-time error:', err)
                        
                print('clipped transform',clipped_transform)
                clipped_meta = origin.meta.copy()
                clipped_meta.update({"driver": "GTiff",
                     "height": clipped_raster.shape[1],
                     "width": clipped_raster.shape[2],
                               "nodata": 0,
                     "transform": clipped_transform})
                print(src.meta,"ds")
                print(clipped_raster[0].shape)
                print(src.crs)
                print(src.meta)
                print(src.shape[1])
                print(src.shape[0])
                print("clipped")
                print(clipped_raster.shape[1])
                print(clipped_raster.shape[2])

                # type
                print(type(clipped_raster)) 

                #old 
                with rio.open("dem.masked1" + ".tif", "w", **clipped_meta) as dest:
                    dest.write(clipped_raster) 
                    
                    
                localname='dem.masked1.tif'
                #Second write is to do with resampling
                with rasterio.open(localname) as nf:
                    print(nf.profile)
                    print(nf.crs)
                    print(nf.meta)
                    dem_r = nf.read(1) # read the entire array
                    clipped_meta = nf.meta.copy()
                    # Resample it here to match the same as Planet
                    #profile = origin.profile
                    clipped_meta.update(transform=transform, driver='GTiff', height=height, width=width)
                    clipped_raster = nf.read(
                    out_shape=(origin.count, height, width),
                    resampling=Resampling.bilinear,
                    )
                    with rio.open("dem.masked2" + ".tif", "w", **clipped_meta) as dest:
                        dest.write(clipped_raster) 
                    # below works , but a better way

                    
                localname='dem.masked2.tif'    
                with rasterio.open(localname) as nf:
                    print(nf.profile)
                    print(nf.crs)
                    print(nf.meta)
                    dem_r = nf.read(1) # read the entire array
                    
                    #print(src.meta)
                    # # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN

                    aug_pla_meta = src.profile
                    # Change the count or number of bands from 4 to 6
                    aug_pla_meta['count'] = 6
                    # Change the data type to float rather than integer
                    aug_pla_meta['dtype'] = "float64"
                    aug_pla_meta
            
                    #convert to float64
                    dem_64 = np.array(dem_r, dtype=numpy.float64)
                    ndvi_64 = np.array(planet_ndvi , dtype=numpy.float64)
                    new_bucket = s3.Bucket('planet-snowcover-imagery-dem-ndvi')
                    temp_file = tempfile.TemporaryFile()
                    #with tempfile.NamedTemporaryFile() as tmpfile:
                    #tmpfile.write(data)
                    #with rasterio.open(tmpfile.name) as dataset:
                    #data_array = dataset.read()
            
                    with tempfile.NamedTemporaryFile() as tmpfile:
                        with rasterio.open(tmpfile.name,
                               'w', **aug_pla_meta) as dstr:
                            dstr.write_band(1, src.read(1))
                            dstr.write_band(2, src.read(2))
                            dstr.write_band(3, src.read(3))
                            dstr.write_band(4, src.read(4))
                            dstr.write_band(5, dem_64)
                            dstr.write_band(6, ndvi_64)
                        dstr.close()   
            
                        s3_client.upload_fileobj(tmpfile, new_bucket.name, my_bucket_object.key)  
                        # Write band calculations to a new raster file
                     
break
# Out:
# planet-snowcover-imagery/20180528_180846_1002_3B_AnalyticMS_SR_clip
# planet-snowcover-imagery:20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12660.tif
# key 20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12660.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756)}
# POLYGON ((-119.190673828125 37.81412370160446, -119.190673828125 37.82280243352756, -119.20166015625 37.82280243352756, -119.20166015625 37.81412370160446, -119.190673828125 37.81412370160446))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.82|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.82283052760954), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.82283052760954)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6950648287314407e-05, 37.82280243352756)}
# planet-snowcover-imagery:20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12661.tif
# key 20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12661.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446)}
# POLYGON ((-119.190673828125 37.80544394934272, -119.190673828125 37.81412370160446, -119.20166015625 37.81412370160446, -119.20166015625 37.80544394934272, -119.190673828125 37.80544394934272))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.81|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.81413756144834), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.81413756144834)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695264113620032e-05, 37.81412370160446)}
# planet-snowcover-imagery:20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12662.tif
# key 20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12662.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724)}
# POLYGON ((-119.190673828125 37.7967631768216, -119.190673828125 37.80544394934272, -119.20166015625 37.80544394934272, -119.20166015625 37.7967631768216, -119.190673828125 37.7967631768216))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.81|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724)} ds
# (279, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724)}
# 512
# 512
# clipped
# 279
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.80544459528715), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.80544459528715)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6954633830321142e-05, 37.805443949342724)}
# planet-snowcover-imagery:20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12663.tif
# key 20180528_180846_1002_3B_AnalyticMS_SR_clip/15/5534/12663.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216)}
# POLYGON ((-119.190673828125 37.78808138412046, -119.190673828125 37.7967631768216, -119.20166015625 37.7967631768216, -119.20166015625 37.78808138412046, -119.190673828125 37.78808138412046))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.80|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.796782786710764), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.796782786710764)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6956626369413197e-05, 37.7967631768216)}
# planet-snowcover-imagery/20180528_180847_1002_3B_AnalyticMS_SR_clip
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5532/12669.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5532/12669.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# POLYGON ((-119.212646484375 37.7359692085905, -119.212646484375 37.74465712069938, -119.2236328125 37.74465712069938, -119.2236328125 37.7359692085905, -119.212646484375 37.7359692085905))
# clipped transform | 0.00, 0.00,-119.22|
# | 0.00,-0.00, 37.74|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.22363751410316,
#        0.0, -3.115758480714683e-05, 37.744687304913214), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.22363751410316,
#        0.0, -3.115758480714683e-05, 37.744687304913214)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5532/12670.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5532/12670.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# POLYGON ((-119.212646484375 37.72728027686004, -119.212646484375 37.7359692085905, -119.2236328125 37.7359692085905, -119.2236328125 37.72728027686004, -119.212646484375 37.72728027686004))
# clipped transform | 0.00, 0.00,-119.22|
# | 0.00,-0.00, 37.74|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504)} ds
# (248, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# 512
# 512
# clipped
# 248
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 248, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.22363751410316,
#        0.0, -3.115758480714683e-05, 37.735994338752015), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 248, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.22363751410316,
#        0.0, -3.115758480714683e-05, 37.735994338752015)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.2236328125,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12665.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12665.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# POLYGON ((-119.20166015625 37.77071473849609, -119.20166015625 37.77939857131877, -119.212646484375 37.77939857131877, -119.212646484375 37.77071473849609, -119.20166015625 37.77071473849609))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.78|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765)} ds
# (280, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# 512
# 512
# clipped
# 280
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.77942801197318), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.77942801197318)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12666.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12666.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# POLYGON ((-119.20166015625 37.7620298857321, -119.20166015625 37.77071473849609, -119.212646484375 37.77071473849609, -119.212646484375 37.7620298857321, -119.20166015625 37.7620298857321))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.77|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)} ds
# (280, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# 512
# 512
# clipped
# 280
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.77073504581199), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.77073504581199)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12667.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12667.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# POLYGON ((-119.20166015625 37.75334401310657, -119.20166015625 37.7620298857321, -119.212646484375 37.7620298857321, -119.212646484375 37.75334401310657, -119.20166015625 37.75334401310657))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.76|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)} ds
# (280, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# 512
# 512
# clipped
# 280
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.76204207965079), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.76204207965079)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12668.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12668.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657)}
# POLYGON ((-119.20166015625 37.74465712069938, -119.20166015625 37.75334401310657, -119.212646484375 37.75334401310657, -119.212646484375 37.74465712069938, -119.20166015625 37.74465712069938))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.75|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657)} ds
# (279, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657)}
# 512
# 512
# clipped
# 279
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.7533491134896), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.7533491134896)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6966586732794497e-05, 37.75334401310657)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12669.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12669.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# POLYGON ((-119.20166015625 37.7359692085905, -119.20166015625 37.74465712069938, -119.212646484375 37.74465712069938, -119.212646484375 37.7359692085905, -119.20166015625 37.7359692085905))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.74|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)} ds
# (280, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# 512
# 512
# clipped
# 280
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.744687304913214), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.744687304913214)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.6968578337647755e-05, 37.74465712069938)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12670.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5533/12670.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# POLYGON ((-119.20166015625 37.72728027686004, -119.20166015625 37.7359692085905, -119.212646484375 37.7359692085905, -119.212646484375 37.72728027686004, -119.20166015625 37.72728027686004))
# clipped transform | 0.00, 0.00,-119.21|
# | 0.00,-0.00, 37.74|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504)} ds
# (248, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# 512
# 512
# clipped
# 248
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 248, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.735994338752015), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 248, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.21267004425104,
#        0.0, -3.115758480714683e-05, 37.735994338752015)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.212646484375,
#        0.0, -1.697056978607059e-05, 37.735969208590504)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12664.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12664.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046)}
# POLYGON ((-119.190673828125 37.77939857131877, -119.190673828125 37.78808138412046, -119.20166015625 37.78808138412046, -119.20166015625 37.77939857131877, -119.190673828125 37.77939857131877))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.79|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046)} ds
# (279, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046)}
# 512
# 512
# clipped
# 279
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.788089820549565), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.788089820549565)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.695861875330995e-05, 37.78808138412046)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12665.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12665.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# POLYGON ((-119.190673828125 37.77071473849609, -119.190673828125 37.77939857131877, -119.20166015625 37.77939857131877, -119.20166015625 37.77071473849609, -119.190673828125 37.77071473849609))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.78|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.77942801197318), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.77942801197318)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.696061098178936e-05, 37.779398571318765)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12666.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12666.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# POLYGON ((-119.190673828125 37.7620298857321, -119.190673828125 37.77071473849609, -119.20166015625 37.77071473849609, -119.20166015625 37.7620298857321, -119.190673828125 37.7620298857321))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.77|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.77073504581199), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.77073504581199)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6962603054657133e-05, 37.77071473849609)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12667.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12667.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# POLYGON ((-119.190673828125 37.75334401310657, -119.190673828125 37.7620298857321, -119.20166015625 37.7620298857321, -119.20166015625 37.75334401310657, -119.190673828125 37.75334401310657))
# clipped transform | 0.00, 0.00,-119.20|
# | 0.00,-0.00, 37.76|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)} ds
# (280, 353)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# 512
# 512
# clipped
# 280
# 353
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.76204207965079), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 353, 'height': 280, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.20167141681412,
#        0.0, -3.115758480714683e-05, 37.76204207965079)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.20166015625,
#        0.0, -1.6964594971746738e-05, 37.762029885732105)}
# planet-snowcover-imagery:20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12668.tif
# key 20180528_180847_1002_3B_AnalyticMS_SR_clip/15/5534/12668.tif
# ...
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.564208984375,
#        0.0, -1.688080260962843e-05, 38.12591462924155)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12619.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12619.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256)}
# POLYGON ((-119.542236328125 38.16911413556085, -119.542236328125 38.1777509666256, -119.55322265625 38.1777509666256, -119.55322265625 38.16911413556085, -119.542236328125 38.16911413556085))
# clipped transform | 0.00, 0.00,-119.55|
# | 0.00,-0.00, 38.18|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256)} ds
# (279, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256)}
# 512
# 512
# clipped
# 279
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.177777733732555), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.177777733732555)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.686881067333723e-05, 38.1777509666256)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12620.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12620.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854)}
# POLYGON ((-119.542236328125 38.16047628099622, -119.542236328125 38.16911413556085, -119.55322265625 38.16911413556085, -119.55322265625 38.16047628099622, -119.542236328125 38.16047628099622))
# clipped transform | 0.00, 0.00,-119.55|
# | 0.00,-0.00, 38.17|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854)} ds
# (278, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854)}
# 512
# 512
# clipped
# 278
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.16911592515616), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.16911592515616)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6870809696548084e-05, 38.169114135560854)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12621.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12621.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622)}
# POLYGON ((-119.542236328125 38.15183740300677, -119.542236328125 38.16047628099622, -119.55322265625 38.16047628099622, -119.55322265625 38.15183740300677, -119.542236328125 38.15183740300677))
# clipped transform | 0.00, 0.00,-119.55|
# | 0.00,-0.00, 38.16|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622)} ds
# (278, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622)}
# 512
# 512
# clipped
# 278
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.160485274164586), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.160485274164586)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6872808573140108e-05, 38.16047628099622)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12622.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12622.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677)}
# POLYGON ((-119.542236328125 38.14319750166765, -119.542236328125 38.15183740300677, -119.55322265625 38.15183740300677, -119.55322265625 38.14319750166765, -119.542236328125 38.14319750166765))
# clipped transform | 0.00, 0.00,-119.55|
# | 0.00,-0.00, 38.15|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677)} ds
# (278, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677)}
# 512
# 512
# clipped
# 278
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.15185462317301), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 278, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.15185462317301)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6874807302974526e-05, 38.15183740300677)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12623.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12623.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765)}
# dem meta origin {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 19874, 'height': 14959, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.80575467105508,
#        0.0, -3.115758480714683e-05, 38.194353568849955)}
# planet origin {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765)}
# POLYGON ((-119.542236328125 38.13455657705413, -119.542236328125 38.14319750166765, -119.55322265625 38.14319750166765, -119.55322265625 38.13455657705413, -119.542236328125 38.13455657705413))
# clipped transform | 0.00, 0.00,-119.55|
# | 0.00,-0.00, 38.14|
# | 0.00, 0.00, 1.00|
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765)} ds
# (279, 354)
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765)}
# 512
# 512
# clipped
# 279
# 354
# <class 'numpy.ndarray'>
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.143223972181424), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 354, 'height': 279, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(3.115758480714683e-05, 0.0, -119.55325360377796,
#        0.0, -3.115758480714683e-05, 38.143223972181424)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765), 'tiled': False, 'interleave': 'band'}
# EPSG:4326
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 512, 'height': 512, 'count': 1, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.687680588578766e-05, 38.14319750166765)}
# planet-snowcover-imagery:20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12624.tif
# key 20180528_181109_1025_3B_AnalyticMS_SR_clip/15/5502/12624.tif
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 512, 'height': 512, 'count': 4, 'crs': CRS.from_dict(init='epsg:4326'), 'transform': Affine(2.1457672119140625e-05, 0.0, -119.55322265625,
#        0.0, -1.6878804321440732e-05, 38.13455657705413)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3a9e85f39611> in <module>()
#      47             with rio.open('out.tiff') as origin:
#      48
# ---> 49                 epsg4326_dem = origin.read(1)
#      50                 print('dem meta origin',origin.meta)
#      51
#
# KeyboardInterrupt:
